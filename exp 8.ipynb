# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushik0212/machine-learning-/blob/main/exp%208.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Linear Regression using Scikit-Learn

from sklearn.linear_model import LinearRegression
import numpy as np

# Sample Dataset
# Hours Studied
X = np.array([1, 2, 3, 4, 5, 6]).reshape(-1, 1)

# Marks Obtained
y = np.array([35, 40, 50, 55, 65, 70])

# Create Linear Regression Model
model = LinearRegression()

# Train the Model
model.fit(X, y)

# Predict for a New Value
hours = np.array([[7]])
predicted_marks = model.predict(hours)

# Display Results
print("Slope (m):", model.coef_[0])
print("Intercept (c):", model.intercept_)
print("Predicted Marks for 7 Hours Study:", predicted_marks[0])
# Out:
# Slope (m): 7.2857142857142865
# Intercept (c): 26.999999999999996
# Predicted Marks for 7 Hours Study: 78.0
